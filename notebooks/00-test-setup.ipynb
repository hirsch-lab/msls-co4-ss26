# %% [markdown]
# # **Test the setup**
#
# <div style="color:#777777;margin-top: -15px;">
# <b>Author</b>: Norman Juchler |
# <b>Course</b>: MSLS CO4 |
# <b>Version</b>: v1.0 <br><br>
# <!-- Date: 14.03.2024 -->
# <!-- Comments: ... -->
# </div>
#
# Use this notebook to check your Python environment.

# %% [markdown]
# ## **Print system summary**
#
# If you have problems with your Python setup, let the tutor know. Be sure to copy the output of the code below, which will help in finding a solution.

# %%
# Jupyter / IPython configuration:
# Automatically reload modules when modified
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
from tools.system_info import print_system_info

print_system_info()
# Out:
# No module named 'soundfile'
# No module named 'sounddevice'
# Repository Info:
# ================
#             Name : msls-co4-ss26.git
#           Commit : 8f063006
#             Date : 2026-03-16 04:12:58
#     Edited files : [ notebooks/00-test-setup.ipynb ]
#
# Python:
# =======
#          Version : 3.13.11
#       Executable : c:\Studium\Master\2. Semester\CO4\rep\venv-msls-co4\Scripts\python.exe
#
# Platform Info:
# ==============
#             OS : Win (Windows)
#        OS Info : Windows-11-10.0.22621-SP0
#        OS Arch : 64bit
#
# Packages:
# =========
#        numpy : 2.4.4
#        scipy : 1.17.1
#       pandas : 3.0.2
#   matplotlib : 3.10.8
#      seaborn : 0.13.2
# OpenCV (cv2) : 4.13.0
# Pillow (PIL) : 12.1.1
#      skimage : 0.26.0
#    soundfile : <N/A>
#  sounddevice : <N/A>
#      jupyter : available
#
# FFmpeg:
# =======
#         ffmpeg : <N/A>
#  ffmpeg-python : <N/A>

# %% [markdown]
# ## **Tested environment**
#
# For reference: The tutor has tested the code in the below environment. It is expected that most of the examples will also run for older and newer versions of the packages. If you encounter compatibility issues, please report the problem as an issue in the Github repository.
# ```lang-none
#
#         Python : 3.10.17
#          numpy : 1.26.4
#          scipy : 1.15.3
#         pandas : 2.1.4
#     matplotlib : 3.10.8
#        seaborn : 0.13.2
#   OpenCV (cv2) : 4.11.0
#   Pillow (PIL) : 12.1.1
#        skimage : 0.25.2
#        nibabel : 5.3.3
#        pydicom : 3.0.1
#      SimpleITK : 2.5.3
#        jupyter : available
#          torch : 2.10.0
#    torchvision : 0.25.0
# ```

# %% [markdown]
# ## **Run a minimal example**
#
# Read and display an image. If you see the image seen [here](../data/imaging4ls-logo-1.jpg), you're good to go. :)

# %%
import cv2 as cv
import tools

img = cv.imread("../data/imaging4ls-logo-1.jpg", cv.IMREAD_COLOR)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
tools.show_image(img, title="Success!")
